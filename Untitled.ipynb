# %%
# IMPORT FILES
import pandas as pd

# File Load
df = pd.read_csv("data/covid.csv")
df.head()
# Out:
#   city county state country  cases  deaths  recovered  tested  active  \
# 0  NaN    NaN   NaN     THA    599     1.0       44.0     NaN     554
# 1  NaN    NaN   NaN     JPN   1086    40.0      235.0     NaN     811
# 2  NaN    NaN   NaN     SGP    455     2.0      144.0     NaN     309
# 3  NaN    NaN   NaN     NPL      2     0.0        1.0     NaN       1
# 4  NaN    NaN   NaN     MYS   1306    10.0      139.0     NaN    1157
#
#     population        lat        long  \
# 0   68414135.0  13.040833  101.544556
# 1  126451398.0  37.873073  137.659785
# 2    5888926.0   1.358568  103.804210
# 3   29384297.0  28.383798   84.102726
# 4   31381992.0   3.930907  109.697195
#
#                                           url  \
# 0  https://github.com/CSSEGISandData/COVID-19
# 1  https://github.com/CSSEGISandData/COVID-19
# 2  https://github.com/CSSEGISandData/COVID-19
# 3  https://github.com/CSSEGISandData/COVID-19
# 4  https://github.com/CSSEGISandData/COVID-19
#
# ...

# %%
df = df.drop(['city', 'county', 'state', 'url', 
              'maintainers', 'rating', 'tz', 'featureId', 'sources', 'curators', 'tested'], axis=1)

# %%
df.head()
# Out:
#   country  cases  deaths  recovered  active   population        lat  \
# 0     THA    599     1.0       44.0     554   68414135.0  13.040833
# 1     JPN   1086    40.0      235.0     811  126451398.0  37.873073
# 2     SGP    455     2.0      144.0     309    5888926.0   1.358568
# 3     NPL      2     0.0        1.0       1   29384297.0  28.383798
# 4     MYS   1306    10.0      139.0    1157   31381992.0   3.930907
#
#          long
# 0  101.544556
# 1  137.659785
# 2  103.804210
# 3   84.102726
# 4  109.697195

# %%
df.to_csv('cleaned_covid.csv')
